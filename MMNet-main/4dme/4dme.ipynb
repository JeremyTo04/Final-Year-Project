# %%
# !git clone https://github.com/JeremyTo04/Final-Year-Project.git
# %cd /content/Final-Year-Project/MMNet-main
# !git pull https://github.com/JeremyTo04/Final-Year-Project.git
# Out:
# Cloning into 'Final-Year-Project'...
# remote: Enumerating objects: 53711, done.
# remote: Counting objects: 100% (12390/12390), done.
# remote: Compressing objects: 100% (11712/11712), done.
# remote: Total 53711 (delta 103), reused 12390 (delta 103), pack-reused 41321 (from 1)
# Receiving objects: 100% (53711/53711), 1.62 GiB | 47.96 MiB/s, done.
# Resolving deltas: 100% (22819/22819), done.
# Updating files: 100% (52092/52092), done.
# [Errno 2] No such file or directory: 'MMNet-main'
# /content
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git pull https://github.com/JeremyTo04/Final-Year-Project.git
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 366 bytes | 183.00 KiB/s, done.
# From https://github.com/JeremyTo04/Final-Year-Project
#  * branch              HEAD       -> FETCH_HEAD
# Updating 7ccdfc57..630a1e20
# Fast-forward
#  MMNet-main/4DME.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# %cd /content/Final-Year-Project/MMNet-main
# Out:
# /content/Final-Year-Project/MMNet-main

# %%
# !pip install timm
# from timm.models.vision_transformer import _cfg
# from CASME2_3 import run_training
# !python PC_module.py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 31.7 MB/s eta 0:00:00
# ...

# %%
# !python CA_block.py

# %%
import os
image_path = '/content/Final-Year-Project/MMNet-main/4dme/micro_short_gray_video/micro short gray video/micro short gray video/S13_1/S13_1_001_01_1/frame_000001409.jpg'

if os.path.exists(image_path):
  print("Image exists.")
else:
  print("Image does not exist.")
# Out:
# Image exists.

# %%
# !python 4DME.py
# Out:
# S59
# num_sub S59
# Train set size: 204
# Validation set size: 2
# [Epoch 1] Training accuracy: 0.4020. Loss: 25.915
# [Epoch 1] Validation accuracy:1.0000. Loss:0.000, F1-score:1.000
# [Epoch 2] Training accuracy: 0.6324. Loss: 17.693
# [Epoch 2] Validation accuracy:0.0000. Loss:5.699, F1-score:0.000
# [Epoch 3] Training accuracy: 0.4559. Loss: 4.260
# [Epoch 3] Validation accuracy:1.0000. Loss:0.000, F1-score:1.000
# [Epoch 4] Training accuracy: 0.5343. Loss: 6.115
# [Epoch 4] Validation accuracy:1.0000. Loss:0.000, F1-score:1.000
# [Epoch 5] Training accuracy: 0.5343. Loss: 6.813
# [Epoch 5] Validation accuracy:0.0000. Loss:4.536, F1-score:0.000
# [Epoch 6] Training accuracy: 0.4804. Loss: 7.008
# [Epoch 6] Validation accuracy:0.5000. Loss:0.763, F1-score:0.333
# [Epoch 7] Training accuracy: 0.5539. Loss: 4.722
# [Epoch 7] Validation accuracy:1.0000. Loss:0.021, F1-score:1.000
# [Epoch 8] Training accuracy: 0.4755. Loss: 3.144
# ...

# %%
# !pwd
# Out:
# /content
